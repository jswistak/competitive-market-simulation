# %%
import yaml
from pathlib import Path

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from notebooks.results_analysis_utils import run_full_analysis


####################################################################################
# Manually adjust the experiment_id to specify which experiment data to load

experiment_id = r"final\results_configs_final\smith1_openai_small_combined"
# experiment_id = r"final\results_configs_final\smith1_gemini_large.yaml_combined"
# experiment_id = r"final\results_configs_final\smith1_openai_large.yaml_combined"

####################################################################################

# construct paths
root_path = Path(globals()['_dh'][0]).parent
results_path = root_path / 'results' / experiment_id

# read the number of simulations from the config file
with open(results_path / 'config_used.yaml', "r") as f:
    config = yaml.safe_load(f)
n_sims = config['experiment']['n_simulations']

# produce the analysis
data, metrics, figs = run_full_analysis(
    results_path,
    n_sims,
    config=config,
    experiment_id=experiment_id,
    independent_rounds=False)
# Out:
# Loaded 10 simulations from smith1_openai_small_combined
#   Iteration history rows: 15000
#   Transaction rows:       289 (from 10/10 sims with trades)
#   Rounds per sim:         5
#
# Competitive Equilibrium:
#   Quantity:       6
#   Price:          2.0000
#   Total surplus:  7.5000
#   Buyer surplus:  3.75
#   Seller surplus: 3.75
#   Demand:         [3.25 3.   2.75 2.5  2.25 2.   1.75 1.5  1.25 1.   0.75]
#   Supply:         [0.75 1.   1.25 1.5  1.75 2.   2.25 2.5  2.75 3.   3.25]
# ...
# MARKET SUMMARY TABLE (Smith 1962 style)
# ...
#        eq_quantity  n_trades  eq_price  mean_price  alpha  efficiency  n_extramarginal
# round
# 1                6       5.5       2.0        2.33   27.6        0.79              1.6
# 2                6       5.7       2.0        2.29   18.2        0.86              1.1
# 3                6       5.7       2.0        2.20   12.6        0.89              0.9
# 4                6       5.8       2.0        2.19   13.6        0.89              1.0
# ...
